# %% [markdown]
# # Recommending products from a transaction log
#
# This notebook is the analysis behind the repository. It reads the saved result
# files rather than recomputing anything, so every number here is the same number
# the README quotes and the same one `scripts/` produced.
#
# The dataset is the UCI Online Retail log: 541,909 invoice lines from a UK
# gift wholesaler, December 2010 to December 2011.
#
# The notebook is in two halves. The first measures what the original
# implementation actually did, because that is what motivated the rewrite. The
# second sets up an evaluation that answers the question the product asks, and
# compares four models under it.
#
# Regenerate the inputs with:
#
# ```
# python scripts/diagnose_original.py
# python scripts/evaluate.py
# ```

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

ROOT = Path.cwd()
while not (ROOT / "data.csv").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent

diagnosis = json.loads((ROOT / "results" / "original_diagnosis.json").read_text())
metrics = pd.read_csv(ROOT / "results" / "metrics.csv")
sweep = pd.read_csv(ROOT / "results" / "cutoff_sensitivity.csv")
run = json.loads((ROOT / "results" / "evaluation_run.json").read_text())

pd.set_option("display.width", 120)
print("loaded results from", ROOT.name)
# Out:
# loaded results from AI-Powered-Recommendation-Engine

# %% [markdown]
# ## Part 1: what the original did
#
# ### 1.1 The target was a z-score declared as a rating
#
# The original scaled `Quantity` with `StandardScaler` and handed the result to
# Surprise as a rating, having told it `rating_scale=(0, 1)`.
#
# Those two statements cannot both be true. A standardised column is centred on
# zero and unbounded above; a quantity column from a wholesaler is extremely
# skewed, because one line of this file orders 80,995 units.

# %%
target = diagnosis["target_vs_declared_scale"]
print(f"rows                        {target['n_rows']:,}")
print(f"range                       [{target['min']:.3f}, {target['max']:.3f}]")
print(f"median                      {target['median']:.3f}")
print(f"inside the declared (0, 1)  {target['share_inside_declared_0_1']:.1%}")
print(f"below zero                  {target['share_below_zero']:.1%}")
# Out:
# rows                        397,884
# range                       [-0.067, 451.577]
# median                      -0.039
# inside the declared (0, 1)  16.0%
# below zero                  83.4%

# %% [markdown]
# So 83.4% of the values a model was asked to predict lie below the bottom of the
# range it was allowed to emit, and only 16% lie inside it.
#
# ### 1.2 The split let the model see its own test set
#
# Surprise was given one row per invoice line rather than one per
# (customer, product) pair. A customer who buys the same product on six invoices
# contributes six separate "ratings", and a random row-level split then puts the
# same pair on both sides.

# %%
leak = diagnosis["split_leakage"]
print(f"rows                              {leak['n_rows']:,}")
print(f"distinct (customer, product) pairs {leak['n_distinct_pairs']:,}")
print(f"rows belonging to a repeated pair  {leak['share_rows_in_a_repeated_pair']:.1%}")
print()
print(f"expected leak rate                 {leak['analytic_leak_rate']:.2%}")
print(f"measured leak rate                 {leak['empirical_leak_rate_mean']:.2%}"
      f"  (sd {leak['empirical_leak_rate_sd']:.2%} over {leak['n_seeds']} seeds)")
# Out:
# rows                              397,884
# distinct (customer, product) pairs 266,792
# rows belonging to a repeated pair  49.3%
#
# expected leak rate                 43.71%
# measured leak rate                 43.70%  (sd 0.15% over 5 seeds)

# %% [markdown]
# Roughly 44% of the test set was pairs the model had trained on directly. The
# analytic and measured figures agree, which is the check that neither is a
# coding accident: a test row leaks unless every other occurrence of its pair
# also landed in test, which has probability about `0.25 ** (n - 1)`.
#
# ### 1.3 The fit diverged, and the clipping hid it
#
# With residuals reaching 451 and a learning rate of 0.005, the SGD updates
# overflow within the first few epochs. Every learned parameter ends up NaN.
#
# That should be loud, and it is not, because Surprise clips predictions with
# Python's builtin `min` and `max` rather than numpy's. `min(1, nan)` returns 1,
# since `nan < 1` is False and `min` falls through to its first argument. A model
# that learned nothing reports a clean in-range prediction of exactly 1.0 with
# `was_impossible` set to False.

# %%
seeds = pd.DataFrame(diagnosis["accuracy_across_seeds"])
view = seeds[[
    "seed", "diverged_to_nan", "rmse", "constant_predictor_rmse",
    "n_distinct_estimates", "share_pinned_at_upper_bound",
]].rename(columns={
    "diverged_to_nan": "diverged",
    "constant_predictor_rmse": "constant_rmse",
    "n_distinct_estimates": "distinct_predictions",
    "share_pinned_at_upper_bound": "pinned_at_1",
})
display(view.round(4))

worse = (seeds["rmse"] > seeds["constant_predictor_rmse"]).sum()
print(f"\nseeds where predicting the training mean beats the model: {worse}/{len(seeds)}")
print(f"seeds where every parameter is NaN:                       "
      f"{seeds['diverged_to_nan'].sum()}/{len(seeds)}")
# Out:
#    seed  diverged    rmse  constant_rmse  distinct_predictions  pinned_at_1
# 0     0      True  1.0314         0.2420                     1       1.0000
# 1     1     False  1.9525         1.9567                 27726       0.0024
# 2     2      True  1.6640         1.3317                     1       1.0000
# 3     3      True  1.0318         0.2436                     1       1.0000
# 4     4      True  1.0281         0.2296                     1       1.0000
# seeds where predicting the training mean beats the model: 4/5
# seeds where every parameter is NaN:                       4/5

# %% [markdown]
# Divergence, "one distinct prediction" and "100% pinned at the upper bound" pick
# out exactly the same four seeds. On the fifth, the one that converges, the model
# beats a constant predictor by 0.2%.
#
# Note also how far apart the RMSE values are across seeds. That is not model
# variance; it is which side of a clip bound a degenerate model happened to land
# on, and it is a good illustration of why a single accuracy number with no
# baseline beside it says very little.
#
# ### 1.4 The endpoint returned the same list to everyone
#
# If every prediction is the same value, sorting by it changes nothing. Python's
# sort is stable, so the "top 10" degenerated into the first ten unseen products
# in column order, which is alphabetical by stock code.

# %%
personal = diagnosis["personalisation"]
print(f"customers probed                {personal['n_users_probed']}")
print(f"distinct top-10 lists returned  {personal['n_distinct_top10_lists']}")
print(f"widest score spread in a list   {personal['max_estimate_spread_within_a_top10']:.2e}")
print(f"list is the alphabetically first unseen products: "
      f"{personal['equals_alphabetically_first_unseen']}")
print()
print("the list every customer received:")
for code_ in personal["example_top10"]:
    print("   ", code_)
# Out:
# customers probed                8
# distinct top-10 lists returned  1
# widest score spread in a list   0.00e+00
# list is the alphabetically first unseen products: True
#
# the list every customer received:
#     10002
#     10080
#     10120
#     10123C
#     10124A
#     10124G
#     10125
#     10133
#     10135
#     11001

# %% [markdown]
# ### 1.5 The zero fill inverted the signal
#
# The user-product pivot filled missing cells with 0 and then used `== 0` as the
# test for "has not bought this". But after standardising, a typical real purchase
# is a small negative number, so the fill value sits *above* most genuine
# purchases rather than below them.

# %%
print(f"median scaled quantity of a real purchase   "
      f"{personal['median_scaled_quantity_of_a_real_purchase']:+.4f}")
print(f"real purchases sitting below the 0 fill     "
      f"{personal['share_real_purchases_below_the_zero_fill']:.1%}")
# Out:
# median scaled quantity of a real purchase   -0.0501
# real purchases sitting below the 0 fill     83.4%

# %% [markdown]
# ## Part 2: measuring the thing the product actually does
#
# ### 2.1 The reframing
#
# There are no ratings in this file. There is only evidence that a purchase
# happened, which is implicit feedback, and it changes three decisions:
#
# - **Binary interactions.** Whether a customer bought a product, not how many.
#   Quantity is a property of the basket, not of preference.
# - **One row per (customer, product).** A repeat purchase is one preference
#   observed again, not a second preference. This is also what removes the leak.
# - **A split by date.** Train on everything before a cutoff, predict what
#   customers bought after it. A random split over a year of trading trains on
#   next month to predict last month.
#
# And the metric changes. RMSE asks how close a predicted number is to a true
# number. A customer sees a short list and either finds something in it or does
# not, so what matters is the ordering: precision, recall, MAP, NDCG and hit rate
# at a cutoff, over binary relevance.

# %%
print(f"split date                    {run['cutoff']}")
print(f"training rows                 {run['train_rows']:,}")
print(f"test rows                     {run['test_rows']:,}")
print(f"customers x products          {run['train_users']:,} x {run['train_items']:,}")
print(f"interactions                  {run['train_interactions']:,}"
      f"  (density {run['train_density']:.4%})")
print(f"evaluable customers           {run['evaluable_users']:,}")
print(f"relevant products per customer  median {run['relevant_per_user_median']:.0f}, "
      f"mean {run['relevant_per_user_mean']:.1f}")
# Out:
# split date                    2011-11-09
# training rows                 330,132
# test rows                     66,205
# customers x products          4,063 x 3,618
# interactions                  230,662  (density 1.5691%)
# evaluable customers           1,287
# relevant products per customer  median 13, mean 20.6

# %% [markdown]
# Evaluable customers are those who appear in the training window and then bought
# something new after the cutoff. Customers seen for the first time after the
# cutoff are excluded: nothing personalised can be said about them, and leaving
# them in would measure cold-start handling while claiming to measure ranking.
#
# ### 2.2 The models
#
# - **Popularity** ranks by how many customers bought each product, identically
#   for everyone. It is in the comparison because a personalised model that
#   cannot beat it is not earning its complexity.
# - **ItemKNN** scores a candidate by its cosine similarity to everything the
#   customer already bought.
# - **PureSVD** is a truncated SVD of the binary matrix, following Cremonesi,
#   Koren and Turrin (RecSys 2010) - the paper that showed RMSE-tuned models can
#   lose to popularity once the ranking is actually measured.
# - **LegacySVD** is the original approach, preserved, so the comparison shows
#   what it scores instead of asserting that it was wrong.

# %%
at_ten = (
    metrics[metrics["k"] == 10]
    .set_index("model")[["precision", "recall", "map", "ndcg", "hit_rate",
                         "coverage", "novelty_bits"]]
    .sort_values("ndcg", ascending=False)
)
display(at_ten.round(4))
# Out:
#             precision  recall     map    ndcg  hit_rate  coverage  novelty_bits
# model
# PureSVD        0.0778  0.0620  0.0483  0.0991    0.4499    0.1996        3.9079
# ItemKNN        0.0484  0.0359  0.0273  0.0586    0.2976    0.1692        3.3714
# Popularity     0.0306  0.0195  0.0128  0.0340    0.2277    0.0193        2.7785
# LegacySVD      0.0013  0.0005  0.0002  0.0010    0.0132    0.0053        7.6553

# %%
order = at_ten.index.tolist()
fig, axes = plt.subplots(1, 4, figsize=(15, 3.8))
panels = [
    ("precision", "Precision@10"),
    ("ndcg", "NDCG@10"),
    ("hit_rate", "Hit rate@10"),
    ("coverage", "Catalogue coverage@10"),
]
for axis, (column, label) in zip(axes, panels, strict=True):
    axis.bar(range(len(order)), at_ten.loc[order, column], color="#4C72B0")
    axis.set_xticks(range(len(order)))
    axis.set_xticklabels(order, rotation=25, ha="right")
    axis.set_title(label)
    axis.spines[["top", "right"]].set_visible(False)
fig.suptitle(
    f"Top-10 performance over {run['evaluable_users']:,} customers, "
    f"split at {run['cutoff']}",
    y=1.06,
)
fig.tight_layout()
plt.show()

# %% [markdown]
# PureSVD finds something the customer went on to buy for 45% of them, against
# popularity's 23%, and it reaches ten times as much of the catalogue doing it.
#
# Coverage is worth reading next to accuracy rather than after it. Popularity only
# ever proposes about 2% of the catalogue, so most of the shop is unreachable
# through it no matter how many customers it is shown to.
#
# The original lands well below the popularity baseline it was never compared
# against.

# %%
fig, axis = plt.subplots(figsize=(6.5, 4.8))
for name in order:
    row = at_ten.loc[name]
    axis.scatter(row["coverage"], row["ndcg"], s=140)
    axis.annotate(name, (row["coverage"], row["ndcg"]),
                  textcoords="offset points", xytext=(9, 5))
axis.set_xlabel("Catalogue coverage@10")
axis.set_ylabel("NDCG@10")
axis.set_title("Accuracy against how much of the shop is reachable")
axis.margins(x=0.22, y=0.15)
axis.spines[["top", "right"]].set_visible(False)
plt.show()

# %% [markdown]
# ### 2.3 Does the ordering survive moving the split date?
#
# One cutoff can flatter one model. The same comparison run at three dates across
# the last two months of trading:

# %%
pivot = sweep.pivot_table(index="model", columns="cutoff", values="ndcg").loc[order]
display(pivot.round(4))

fig, axis = plt.subplots(figsize=(7, 4))
for name in order:
    series = sweep[sweep["model"] == name].sort_values("cutoff")
    axis.plot(series["cutoff"], series["ndcg"], marker="o", label=name)
axis.set_ylabel("NDCG@10")
axis.set_xlabel("split date")
axis.set_title("The ordering is the same at every split date")
axis.legend(frameon=False)
axis.spines[["top", "right"]].set_visible(False)
plt.show()
# Out:
# cutoff      2011-10-09  2011-11-09  2011-11-24
# model
# PureSVD         0.1044      0.0991      0.0780
# ItemKNN         0.0735      0.0586      0.0418
# Popularity      0.0419      0.0340      0.0263
# LegacySVD       0.0015      0.0010      0.0008

# %% [markdown]
# The absolute numbers move with the size of the held-out window, which is
# expected. The ordering does not, so it is a property of the models rather than
# of where the boundary was drawn.
#
# ## What this leaves
#
# PureSVD is what the service ships. It is a 50-factor truncated SVD of a binary
# matrix: about 0.15 seconds to fit and 1.9 ms to answer a request, which is
# worth stating because none of the accuracy above would matter if it could not
# be served.
#
# The honest limits are in the README's scope section. The main ones: this is a
# single wholesaler's year, evaluated offline, and offline ranking metrics are a
# proxy for what an A/B test would measure, not a substitute for it.
